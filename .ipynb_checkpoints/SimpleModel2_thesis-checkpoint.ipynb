# %% [markdown]
# # Explanation of the task:
#
# This is the classic Emotion Recognition Classification task. Given a conversation, involving 2 or more parties, for each message/utterance, we want to predict an emotion related to it.
#
#
# Consider the example:
#
# **Person A**: "Hello! I am very happy" (happiness)
#
# **Person B**: "Why? I am very angry"   (anger)
#
# ## First model idea:
# - inputs: sequence of utterances, sequence of emotions.
# - For each: Linear Layers
# - Fusion model
#
# - Loss: cross-entropy

# %% [markdown]
# # Preprocessing:
#
# Consider the each conversation as just a sequence of words:
# $$
# [[utt, utt, \cdots], \cdots ] \longrightarrow [[word, word , \cdots], \cdots]
# $$
#
# In here, we add a separator token "sep". It will serve to indicate when a utteration is over, and another one starts. We also add a padding token at the end to ensure that all inputs have same dimention.

# %%
! pip install nltk
! pip install torch
! pip install pandas
! pip install gensim
! pip install datasets
! pip install matplotlib
! pip install tqdm
! pip install torchinfo
! pip install requests json
# eventually include tensorboard
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (3.7)
# Requirement already satisfied: click in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from nltk) (4.65.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in ./.local/lib/python3.11/site-packages (2.2.0)
# Requirement already satisfied: filelock in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.local/lib/python3.11/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from torch) (2.8.4)
# Requirement already satisfied: jinja2 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in ./.local/lib/python3.11/site-packages (from torch) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.local/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.local/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.local/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.local/lib/python3.11/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.local/lib/python3.11/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.local/lib/python3.11/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.local/lib/python3.11/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.local/lib/python3.11/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.local/lib/python3.11/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in ./.local/lib/python3.11/site-packages (from torch) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.local/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in ./.local/lib/python3.11/site-packages (from torch) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.local/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.3.101)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from sympy->torch) (1.2.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in ./.local/lib/python3.11/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (4.3.0)
# Requirement already satisfied: numpy>=1.18.5 in ./.local/lib/python3.11/site-packages (from gensim) (1.24.4)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from gensim) (5.2.1)
# Requirement already satisfied: FuzzyTM>=0.4.0 in ./.local/lib/python3.11/site-packages (from gensim) (2.0.9)
# Requirement already satisfied: pandas in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from FuzzyTM>=0.4.0->gensim) (1.5.3)
# Requirement already satisfied: pyfume in ./.local/lib/python3.11/site-packages (from FuzzyTM>=0.4.0->gensim) (0.3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2022.7)
# Requirement already satisfied: simpful==2.12.0 in ./.local/lib/python3.11/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.12.0)
# Requirement already satisfied: fst-pso==1.8.1 in ./.local/lib/python3.11/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: miniful in ./.local/lib/python3.11/site-packages (from fst-pso==1.8.1->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Requirement already satisfied: six>=1.5 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas->FuzzyTM>=0.4.0->gensim) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (2.12.0)
# Requirement already satisfied: numpy>=1.17 in ./.local/lib/python3.11/site-packages (from datasets) (1.24.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from datasets) (11.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in ./.local/lib/python3.11/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: multiprocess in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in ./.local/lib/python3.11/site-packages (from datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from datasets) (3.8.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in ./.local/lib/python3.11/site-packages (from datasets) (0.25.1)
# Requirement already satisfied: packaging in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from datasets) (23.0)
# Requirement already satisfied: responses<0.19 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from datasets) (0.13.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: filelock in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.local/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.9.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2023.5.7)
# Requirement already satisfied: six in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from responses<0.19->datasets) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from pandas->datasets) (2022.7)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in ./.local/lib/python3.11/site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages (4.65.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torchinfo in ./.local/lib/python3.11/site-packages (1.8.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in ./.local/lib/python3.11/site-packages (2.31.0)
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json

# %%
import torch
import os
import matplotlib.pyplot as plt
import gensim
import json
import requests
import heapq

from nltk.tokenize import TweetTokenizer
from datasets import load_dataset
from torch.utils.data import Dataset, DataLoader, random_split
from collections import Counter

import pandas as pd
import numpy as np

# %%
! wget https://dl.fbaipublicfiles.com/fasttext/vectors-english/wiki-news-300d-1M.vec.zip
! unzip wiki-news-300d-1M.vec.zip
! rm wiki-news-300d-1M.vec.zip
# Out:
# --2025-01-22 14:53:59--  https://dl.fbaipublicfiles.com/fasttext/vectors-english/wiki-news-300d-1M.vec.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 18.164.52.45, 18.164.52.20, 18.164.52.25, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|18.164.52.45|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 681808098 (650M) [application/zip]
# Saving to: ‘wiki-news-300d-1M.vec.zip’
#
# wiki-news-300d-1M.v 100%[===================>] 650.22M   108MB/s    in 6.0s
#
# 2025-01-22 14:54:08 (109 MB/s) - ‘wiki-news-300d-1M.vec.zip’ saved [681808098/681808098]
#
# Archive:  wiki-news-300d-1M.vec.zip
# replace wiki-news-300d-1M.vec? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
## taken from template
encoder_model = gensim.models.KeyedVectors.load_word2vec_format("wiki-news-300d-1M.vec", binary = False)

# %%
## We create the embeddings and find the vocab
import copy
unk_token, sep_token = '<unk>','<sep>'
embedding_vectors = torch.from_numpy(encoder_model.vectors) ## TODO: remove least frequent
pretrained_vocab = copy.deepcopy(encoder_model.index_to_key)
pretrained_vocab[:0] = [unk_token,sep_token]

stoi = {word: i for i, word in enumerate(pretrained_vocab)}
itos = {i: word for i, word in enumerate(pretrained_vocab)}

pretrained_embeddings = torch.cat((torch.ones(1,embedding_vectors.shape[1]),embedding_vectors))
pretrained_embeddings = torch.cat((-torch.ones(1,embedding_vectors.shape[1]),embedding_vectors))

# %%
from nltk.tokenize import TweetTokenizer
from tqdm.notebook import tqdm

max_size = 50
## By using the template that was shared, we can process the inputs in a very similar way
tok = TweetTokenizer()
def tokenize_text_extend_emotions(text,emotion,stoi): ## utteration : string -> list of tokenized words : [int]
  text = tok.tokenize(text)
  text = [stoi[word] if word in stoi else stoi['<unk>'] for word in text]
  return text, [emotion]*len(text)

def concat_utt(dialog, emotions, stoi): ## list of utterations : [string] -> list of list of tokenized words : [int]
  tokenized_and_extended = [tokenize_text_extend_emotions(t,e,stoi) for t,e in zip(dialog,emotions)]
  dialog = [i[0] for i in tokenized_and_extended]
  emotions = [i[1] for i in tokenized_and_extended]
  dialog_flat = []
  emotions_extended = []
  for i in range(len(dialog) - 1):
    dialog[i].append(stoi["<sep>"])
    emotions[i].append(7) ## number of emotions
  for i in range(len(dialog)):
    dialog_flat.extend(dialog[i])
    emotions_extended.extend(emotions[i])
  return dialog_flat,emotions_extended

def preprocess_data(X,Y,stoi): ## list of lists of utterations : [[string]] -> list of lists of tokenized words : [[int]]
  X_processed = []
  Y_processed = []
  for i in tqdm(range(len(X))):
    X_processed.append(concat_utt(X[i],Y[i],stoi)[0])
    Y_processed.append(concat_utt(X[i],Y[i],stoi)[1])
  return X_processed, Y_processed

def get_target(X,Y): ## generates the target values and input values
  text_input = [i[:-1] for i in X]
  text_target = [i[1:] for i in X]
  emotion_input = [i[:-1] for i in Y]
  emotion_target = [i[1:] for i in Y]
  return text_input, text_target, emotion_input, emotion_target


## Check the following example:
dialog_example = ["hello, I am a I robot!","I am greek"]
emotions_example = [1,2] ## random emotions...

flatten_dialog, flatten_emotions = concat_utt(dialog_example,emotions_example,stoi)
print(f"{dialog_example} becomes {flatten_dialog}")
print(f"{emotions_example} becomes {flatten_emotions}")
# Out:
# ['hello, I am a I robot!', 'I am greek'] becomes [13171, 2, 30, 783, 9, 30, 6871, 79, 1, 30, 783, 22504]
# [1, 2] becomes [1, 1, 1, 1, 1, 1, 1, 1, 7, 2, 2, 2]

# %% [markdown]
# ## DataLoader not implemented yet:

# %%
## Modify this after changing the preprocessing.
class DailyDialogDataset(Dataset):
  def __init__(self, texts, emotions,target_texts,target_emotions):
  # Dataset object for Daily Dialog dataset
    self.texts = texts                     ## tokenized text
    self.emotions = emotions               ## tokenized emotions
    self.target_texts = target_texts       ## target text for loss computation
    self.target_emotions = target_emotions ## target emotions for loss computation

  def __len__(self):
    return len(self.texts)

  def __getitem__(self, idx):
    item = {
                'texts': np.array(self.texts[idx]),
             'emotions': np.array(self.emotions[idx]),
         'target_texts': np.array(self.target_texts[idx]),
      'target_emotions': np.array(self.target_emotions[idx])
    }
    return item
class MeldDataset(Dataset):
  def __init__(self, texts, emotions,target_texts,target_emotions):
  # Dataset object for MELD dataset
    self.texts = texts                     ## tokenized text
    self.emotions = emotions               ## tokenized emotions
    self.target_texts = target_texts       ## target text for loss computation
    self.target_emotions = target_emotions ## target emotions for loss computation

  def __len__(self):
    return len(self.texts)

  def __getitem__(self, idx):
    item = {
                'texts': np.array(self.texts[idx]),
             'emotions': np.array(self.emotions[idx]),
         'target_texts': np.array(self.target_texts[idx]),
      'target_emotions': np.array(self.target_emotions[idx])
    }
    return item
class EmorynlpDataset(Dataset):
  def __init__(self, texts, emotions,target_texts,target_emotions):
    # Dataset object for EmoryNLP dataset
    self.texts = texts                     ## tokenized text
    self.emotions = emotions               ## tokenized emotions
    self.target_texts = target_texts       ## target text for loss computation
    self.target_emotions = target_emotions ## target emotions for loss computation

  def __len__(self):
    return len(self.texts)

  def __getitem__(self, idx):
    item = {
                 'texts': np.array(self.texts[idx]),
              'emotions': np.array(self.emotions[idx]),
          'target_texts': np.array(self.target_texts[idx]),
      'target_emotions' : np.array(self.target_emotions[idx])
    }
    return item

# %% [markdown]
# Here we will extract the data and process it:

# %%
! wget https://raw.githubusercontent.com/declare-lab/MELD/refs/heads/master/data/MELD/dev_sent_emo.csv
! wget https://raw.githubusercontent.com/declare-lab/MELD/refs/heads/master/data/MELD/test_sent_emo.csv
! wget https://raw.githubusercontent.com/declare-lab/MELD/refs/heads/master/data/MELD/train_sent_emo.csv
# Out:
# --2025-01-22 14:30:55--  https://raw.githubusercontent.com/declare-lab/MELD/refs/heads/master/data/MELD/dev_sent_emo.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 121640 (119K) [text/plain]
# Saving to: ‘dev_sent_emo.csv.4’
#
# dev_sent_emo.csv.4  100%[===================>] 118.79K  --.-KB/s    in 0.02s
#
# 2025-01-22 14:30:55 (4.78 MB/s) - ‘dev_sent_emo.csv.4’ saved [121640/121640]
#
# --2025-01-22 14:30:55--  https://raw.githubusercontent.com/declare-lab/MELD/refs/heads/master/data/MELD/test_sent_emo.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 294526 (288K) [text/plain]
# Saving to: ‘test_sent_emo.csv.4’
#
# test_sent_emo.csv.4 100%[===================>] 287.62K  --.-KB/s    in 0.03s
#
# 2025-01-22 14:30:56 (8.34 MB/s) - ‘test_sent_emo.csv.4’ saved [294526/294526]
#
# --2025-01-22 14:30:56--  https://raw.githubusercontent.com/declare-lab/MELD/refs/heads/master/data/MELD/train_sent_emo.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1119290 (1.1M) [text/plain]
# Saving to: ‘train_sent_emo.csv.4’
#
# train_sent_emo.csv. 100%[===================>]   1.07M  --.-KB/s    in 0.05s
#
# 2025-01-22 14:30:56 (20.8 MB/s) - ‘train_sent_emo.csv.4’ saved [1119290/1119290]

# %%
#data_dd = load_dataset('daily_dialog') ## daily conversations

data_meld_train = pd.read_csv('train_sent_emo.csv').drop(columns=['Sr No.','Speaker','Sentiment','Season','Episode','StartTime','EndTime'])
data_meld_val = pd.read_csv('dev_sent_emo.csv').drop(columns=['Sr No.','Speaker','Sentiment','Season','Episode','StartTime','EndTime'])
data_meld_test = pd.read_csv('test_sent_emo.csv').drop(columns=['Sr No.','Speaker','Sentiment','Season','Episode','StartTime','EndTime'])

## For Daily Dialog:
"""
X_train_dd = data_dd['train']['dialog']
Y_train_dd = data_dd['train']['emotion']
X_test_dd = data_dd['test']['dialog']
Y_test_dd = data_dd['test']['emotion']
X_val_dd = data_dd['validation']['dialog']
Y_val_dd = data_dd['validation']['emotion']
"""
## For MELD
def change_Y(Y,lookup=None):
  lookup = {} if lookup is None else lookup
  k = 0
  for i in range(len(Y)):
    for j in range(len(Y[i])):
      if Y[i][j] not in lookup:
        lookup[Y[i][j]] = k
        Y[i][j] = k
        k += 1
      else:
        Y[i][j] = lookup[Y[i][j]]
  return Y, lookup


def parse_meld(df,lookup = None):
  X, Y = {}, {}
  for _, row in df.iterrows():
    dialog_id = row['Dialogue_ID']
    if dialog_id not in X:
      X[dialog_id] = []
      Y[dialog_id] = []
    X[dialog_id].append(row['Utterance'])
    Y[dialog_id].append(row['Emotion'])
  X = list(X.values())
  Y = list(Y.values())
  Y,lookup = change_Y(Y,lookup)
  return X, Y, lookup

X_train_meld, Y_train_meld, lookup_meld = parse_meld(data_meld_train)
X_test_meld, Y_test_meld, _ = parse_meld(data_meld_test,lookup_meld)
X_val_meld, Y_val_meld, _ = parse_meld(data_meld_val,lookup_meld)


## For EmoryNLP:
def parse_seasons(episodes,lookup=None): ## annoying parsing
  lookup = {} if lookup is None else lookup
  X = []
  Y = []
  for episode in episodes:
    for scene in episode['scenes']:
      dialog = []
      emotion = []
      for utterance in scene['utterances']:
        if utterance['transcript'] != '':
          dialog.append(utterance['transcript'])
          emotion.append(utterance['emotion'])
      X.append(dialog)
      Y.append(emotion)
  Y,lookup = change_Y(Y)
  return X, Y, lookup

def parse_emory(): ## getting from the web
  json_train = 'https://raw.githubusercontent.com/emorynlp/emotion-detection/refs/heads/master/json/emotion-detection-trn.json'
  json_test = 'https://raw.githubusercontent.com/emorynlp/emotion-detection/refs/heads/master/json/emotion-detection-dev.json'
  json_val = 'https://raw.githubusercontent.com/emorynlp/emotion-detection/refs/heads/master/json/emotion-detection-tst.json'
  train = requests.get(json_train)
  test = requests.get(json_test)
  val = requests.get(json_val)

  train = json.loads(train.text)['episodes']
  test = json.loads(test.text)['episodes']
  val = json.loads(val.text)['episodes']
  X_train, Y_train, lookup = parse_seasons(train)
  X_test, Y_test, _ = parse_seasons(test)
  X_val, Y_val, _ = parse_seasons(val)
  return X_train, Y_train, X_test, Y_test, X_val, Y_val, lookup


## to get top n most frequent words:


def get_topk(X,k): ## get the top k most frequent words - has to get a flatten version of the input
  X = [j for i in X for j in i]
  flat_X = [] 
  for i in X:
    flat_X.extend(tok.tokenize(i))
  c = Counter(flat_X)
  top_k = heapq.nlargest(k, c.items(), key=lambda x: x[1])
  new_stoi = {'<unk>' : 0, '<sep>' : 1}
  res = []
  k = 2
  for (word,_) in top_k:
    if word in stoi:
      new_stoi[word] = k
      k += 1
      res.append(pretrained_embeddings[stoi[word]])
  res[:0] = [torch.ones(embedding_vectors.shape[1]),-torch.ones(embedding_vectors.shape[1])]
  new_itos = {index : word for (word,index) in new_stoi.items()}
  return torch.stack(res), new_stoi, new_itos

X_train_emory, Y_train_emory, X_test_emory, Y_test_emory, X_val_emory, Y_val_emory, lookup_emory = parse_emory()
embeddings_emory, stoi_emory,itos_emory = get_topk(X_train_emory, 50000)

# %%
# For Daily Dialog (probably not going to be used anymore)
""" 
X_train_dd, Y_train_dd = preprocess_data(X_train_dd,Y_train_dd)
X_train_dd,X_train_target_dd, Y_train_dd, Y_train_target_dd = get_target(X_train_dd,Y_train_dd)
X_test_dd, Y_test_dd = preprocess_data(X_test_dd,Y_test_dd)
X_test_dd,X_test_target_dd, Y_test_dd, Y_test_target_dd = get_target(X_test_dd,Y_test_dd)
X_val_dd, Y_val_dd = preprocess_data(X_val_dd,Y_val_dd)
X_val_dd, X_val_target_dd, Y_val_dd, Y_val_target_dd = get_target(X_val_dd,Y_val_dd)
"""
# For MELD
"""
X_train_meld, Y_train_meld = preprocess_data(X_train_meld,Y_train_meld)
X_train_meld,X_train_target_meld, Y_train_meld, Y_train_target_meld = get_target(X_train_meld,Y_train_meld)
X_test_meld, Y_test_meld = preprocess_data(X_test_meld,Y_test_meld)
X_test_meld,X_test_target_meld, Y_test_meld, Y_test_target_meld = get_target(X_test_meld,Y_test_meld)
X_val_meld, Y_val_meld = preprocess_data(X_val_meld,Y_val_meld)
X_val_meld, X_val_target_meld, Y_val_meld, Y_val_target_meld = get_target(X_val_meld,Y_val_meld)
"""
## For EmoryNLP:
X_train_emory, Y_train_emory = preprocess_data(X_train_emory,Y_train_emory,stoi_emory)
X_train_emory,X_train_target_emory, Y_train_emory, Y_train_target_emory = get_target(X_train_emory,Y_train_emory)
X_test_emory, Y_test_emory = preprocess_data(X_test_emory,Y_test_emory,stoi_emory)
X_test_emory,X_test_target_emory, Y_test_emory, Y_test_target_emory = get_target(X_test_emory,Y_test_emory)
X_val_emory, Y_val_emory = preprocess_data(X_val_emory,Y_val_emory,stoi_emory)
X_val_emory, X_val_target_emory, Y_val_emory, Y_val_target_emory = get_target(X_val_emory,Y_val_emory)
## Just checking if nothing wrong happened
# Out:
#   0%|          | 0/713 [00:00<?, ?it/s]
#   0%|          | 0/99 [00:00<?, ?it/s]
#   0%|          | 0/85 [00:00<?, ?it/s]

# %%
batch_size = 1 ## try with other values. 5 Might be too little!
"""
train_data_dd = DailyDialogDataset(X_train_dd,Y_train_dd,X_train_target_dd,Y_train_target_dd)
test_data_dd = DailyDialogDataset(X_test_target_dd,Y_test_target_dd,X_test_target_dd,Y_test_target_dd)
val_data_dd = DailyDialogDataset(X_val_target_dd,Y_val_target_dd,X_val_target_dd,Y_val_target_dd)

train_data_meld = MeldDataset(X_train_meld,Y_train_meld,X_train_target_meld,Y_train_target_meld)
test_data_meld = MeldDataset(X_test_meld,Y_test_meld,X_test_target_meld,Y_test_target_meld)
val_data_meld = MeldDataset(X_val_meld,Y_val_meld,X_val_target_meld,Y_val_target_meld)
"""
train_data_emory = EmorynlpDataset(X_train_emory,Y_train_emory,X_train_target_emory,Y_train_target_emory)
test_data_emory = EmorynlpDataset(X_test_emory,Y_test_emory,X_test_target_emory,Y_test_target_emory)
val_data_emory = EmorynlpDataset(X_val_emory,Y_val_emory,X_val_target_emory,Y_val_target_emory)

"""
train_loader_dd = DataLoader(train_data_dd, batch_size=batch_size,shuffle = True,)
test_loader_dd = DataLoader(test_data_dd, batch_size=batch_size,shuffle = True)
val_loader_dd = DataLoader(val_data_dd, batch_size=batch_size, shuffle = True)

train_loader_meld = DataLoader(train_data_meld, batch_size=batch_size,shuffle = True,)
test_loader_meld = DataLoader(test_data_meld, batch_size=batch_size,shuffle = True)
val_loader_meld = DataLoader(val_data_meld, batch_size=batch_size, shuffle = True)
"""
train_loader_emory = DataLoader(train_data_emory, batch_size=batch_size,shuffle = True)
test_loader_emory = DataLoader(test_data_emory, batch_size=batch_size,shuffle = True)
val_loader_emory = DataLoader(val_data_emory, batch_size=batch_size, shuffle = True)

## Example:

# %% [markdown]
# # The model:
# ## archtecture
# - 2 input channels: word encoding, emotion encoding
# - dinamically updated weights: $w_1, w_2 = w1 + w2, w1$ (Not implemented yet)
# ### For each channel:
#    - 3 sequential Linear layers
# - fusion linear layer through concatenation
# - 2 output channels which contain a linear layer each

# %%
import torch.nn as nn
import torch.nn.functional as F
class SimpleModel(nn.Module):
  def __init__(self, embeddings,emo_dim, n_emotion, n_vocab):
    super(SimpleModel,self).__init__()
    ## word_dim = 300
    self.embedding_layer_text = nn.Embedding.from_pretrained(embeddings, freeze=True)
    self.embedding_layer_emotion = nn.Embedding(n_emotion, emo_dim)
    ## Channel for utterances/words:
    self.Linear_utt1 = nn.Linear(300,80)
    self.Linear_utt2 = nn.Linear(80,80)
    self.Linear_utt3 = nn.Linear(80,80)

    ## Channel for emotions:
    self.Linear_emo1 = nn.Linear(emo_dim,80)
    self.Linear_emo2 = nn.Linear(80,80)
    self.Linear_emo3 = nn.Linear(80,80)
    # self.Linear_emo3.requires_grad = False

    ## fusion by concatenation and Linear layer:
    self.Linear_fus = nn.Linear(160,300)

    ## We concatenate and do linear again (2 different concatenations)
    self.Linear_utt_final1 = nn.Linear(380, 180)
    self.Linear_utt_final2 = nn.Linear(180, 100)
    self.Linear_utt_final3 = nn.Linear(100, 200)
    self.Linear_utt_final = nn.Linear(200, n_vocab)


    self.Linear_emo_final = nn.Linear(380, n_emotion)

    self.softmax = nn.Softmax(dim=0)

  def init_hidden(self):
    pass # see later how to init this

  def forward(self, text, emotion, hidden):
    with torch.no_grad():
      text = self.embedding_layer_text(text)
    text = self.Linear_utt1(text)
    text = self.Linear_utt2(text)
    text = self.Linear_utt3(text)

    emotion = self.embedding_layer_emotion(emotion)
    emotion = self.Linear_emo1(emotion)
    emotion = self.Linear_emo2(emotion)
    emotion = self.Linear_emo3(emotion)

    hidden = hidden +  emotion*0.3 + text*0.7
    z = torch.cat((text,emotion),-1)
    z = self.Linear_fus(z)

    text = torch.cat((z,text),-1)
    text = self.Linear_utt_final1(text)
    text = self.Linear_utt_final2(text)
    text = self.Linear_utt_final3(text)
    text = self.Linear_utt_final(text)
    text = self.softmax(text)
    emotion = torch.cat((z,hidden),-1)
    emotion = self.Linear_emo_final(emotion)
    emotion = self.softmax(emotion)

    return text, emotion, hidden
    #return emotion

# %%
import torch.optim as optim
from tqdm.notebook import tqdm
def activate_gpu(force_cpu=False): # check if gpu available ; code taken from template
    device = "cpu"
    if not force_cpu:
        if torch.cuda.is_available(): # for both Nvidia and AMD GPUs
            device = 'cuda'
            print('DEVICE = ', torch.cuda.get_device_name(0))
        elif torch.backends.mps.is_available(): # for mac ARM chipset
            device = 'mps'
            print('DEVICE = ', "mps" )
        else: # for cpu only
            device = 'cpu'
            print('DEVICE = ', 'CPU', "blue")
    return device

## train functions

def train_batch(model, batch, optimizer,lr):
  loss = 0
  loss_fn = nn.CrossEntropyLoss()
  hidden = torch.zeros(80, requires_grad=True).to(device)
  optimizer.zero_grad()
  inp_emotion = batch['emotions'][0]

  for t in range(len(batch['texts'])):
    inp_token = batch['texts'][t]
    target_token = batch['target_texts'][t]
    target_emotion = batch['target_emotions'][t]

    pt, pe, hidden = model.forward(inp_token,inp_emotion,hidden)
    loss1 = loss_fn(pe,target_emotion) + loss_fn(pt,target_token) ## test: removing the token loss
    inp_emotion = torch.argmax(pe)
    loss += loss1
  loss.backward()
  optimizer.step()
  return loss.item()/len(batch['texts']) ## average

def train(model, train_loader, epochs, device):
  optimizer = optim.Adam(model.parameters())
  loss_fn = nn.CrossEntropyLoss()
  model.train()
  model = model.to(device)
  loss_to_plot = []
  lr = 0.01 ## impltement this later (vary the learning rate)
  for epoch in range(epochs):
    losses = []
    print(f"Epoch {epoch+1}/{epochs}")
    for it, batch in tqdm(enumerate(train_loader),total = train_loader.__len__()):
      batch = {'texts': torch.from_numpy(batch['texts']).to(device),
               'emotions': torch.from_numpy(batch['emotions']).to(device),
               'target_texts': torch.from_numpy(batch['target_texts']).view(-1).to(device), ## reshape is necessary to compare predictions
               'target_emotions': torch.from_numpy(batch['target_emotions']).view(-1).to(device)
      }
      if lr % 20 == 0:
        lr /= 10
      losses.append(train_batch(model, batch, optimizer,lr))
    loss_to_plot.append(sum(losses)/len(losses))
    print(f"loss: ",loss_to_plot[-1])
  return loss_to_plot

# %%
from torchinfo import summary

## Setting some hyper parameters:
device = activate_gpu()
emotion_dim = 30
n_emotions = 8
n_words = len(stoi_emory)

model = SimpleModel(embeddings_emory,emotion_dim,n_emotions,n_words)
print(device)
print(summary(model))
# Out:
# DEVICE =  CPU blue
# cpu
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# SimpleModel                              --
# ├─Embedding: 1-1                         (2,097,900)
# ├─Embedding: 1-2                         240
# ├─Linear: 1-3                            24,080
# ├─Linear: 1-4                            6,480
# ├─Linear: 1-5                            6,480
# ├─Linear: 1-6                            2,480
# ├─Linear: 1-7                            6,480
# ├─Linear: 1-8                            6,480
# ├─Linear: 1-9                            48,300
# ├─Linear: 1-10                           68,580
# ├─Linear: 1-11                           18,100
# ├─Linear: 1-12                           20,200
# ├─Linear: 1-13                           1,405,593
# ├─Linear: 1-14                           3,048
# ├─Softmax: 1-15                          --
# =================================================================
# Total params: 3,714,441
# Trainable params: 1,616,541
# Non-trainable params: 2,097,900
# =================================================================

# %%
epochs = 7

# Do later : increase batch size!
## training in the cpu with the loss for the tokens excrutiatingly slow
## It becomes faster when we train with only the loss for the emotions
losses = train(model, train_data_emory , epochs, device)

## it quite affects the predictions...
plt.plot(np.arange(1,epochs+1),losses)
# Out:
# Epoch 1/7
#   0%|          | 0/713 [00:00<?, ?it/s]
# loss:  10.808662010114402
# Epoch 2/7
#   0%|          | 0/713 [00:00<?, ?it/s]
# loss:  10.819662353053156
# Epoch 3/7
#   0%|          | 0/713 [00:00<?, ?it/s]
# loss:  10.813202115712054
# Epoch 4/7
#   0%|          | 0/713 [00:00<?, ?it/s]
# loss:  10.813592705941899
# Epoch 5/7
#   0%|          | 0/713 [00:00<?, ?it/s]
# loss:  10.813592705941899
# Epoch 6/7
#   0%|          | 0/713 [00:00<?, ?it/s]
# loss:  10.813592705941899
# Epoch 7/7
#   0%|          | 0/713 [00:00<?, ?it/s]
# loss:  10.813592705941899

# %% [markdown]
# # Descrition of the issues faced:
#
# It is not trivial of how to deal with the gradient flow in this case. Maybe by fixing the 2 matrix it would go better. Or just train the matrix with fixed weight. And update the weight not in the forward pass. but in the prediction. this way we can cache the weight and everytime we restart, we will be ok.
#
# I believe that, the issue of this approach specifically is updating directly the weights, and not, a hidden state, for instance.
#
# # Problem with Daily Dialog:
# By plotting the frequency of each emotion, we notice that the dataset is truly not diversified. It has essentially only 2 emotions. This is not ideal, because the models will most likely overfit into predicting those 2 emotions...

# %%
def compute_test_loss(model,loss_fn,data_loader,device,itos):
  model.eval()
  losses = []
  accs = []
  preds = [] ## predictions will be here
  prec = 0
  trues = [] ## true values will be here
  words = []

  for it,batch in tqdm(enumerate(data_loader),total=data_loader.__len__()):
    batch = {'texts' : batch['texts'].view(-1).to(device),
             'emotions': batch['emotions'].view(-1).to(device),
             'target_texts': batch['target_texts'].view(-1).to(device),
             'target_emotions': batch['target_emotions'].view(-1).to(device)}
    hidden = torch.zeros(80, requires_grad=True).to(device)
    for t in range(len(batch['texts'])):
      inp_token = batch['texts'][t]
      emotion = batch['emotions'][t]
      target_token = batch['target_texts'][t]
      target_emotion = batch['target_emotions'][t]
      pt , pe, hidden = model.forward(inp_token,emotion,hidden)
      loss1 = loss_fn(pe,target_emotion) + loss_fn(pt,target_token)
      pe = torch.argmax(pe)
      words.append(itos[target_token.item()] if target_token.item() in itos else '<unk>')
      preds.append(pe.item())
      trues.append(target_emotion.item())
      if pe == target_emotion:
        accs.append(1)
      else:
        accs.append(0)
      losses.append(loss1.item())
  
  print("average loss: ", sum(losses)/len(losses))
  print("average acc: ", sum(accs)/len(accs))
  return trues, preds, words

# %%
trues, preds, words = compute_test_loss(model,nn.CrossEntropyLoss(),test_loader_emory,device,itos_emory)
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]
# average loss:  10.806726465994865
# average acc:  0.2558202053873864

# %%
from sklearn.metrics import classification_report, confusion_matrix
names = [f'{i}' for i in range(1,9)]
print(classification_report(np.array(trues).flatten(), np.array(preds).flatten(), target_names=names))
print(confusion_matrix(trues,preds))

## to visually see how it compares:
l_ = {e:t for (t,e) in lookup_emory.items()}

l_[7] = "NE"
x1 = list(map(lambda e : l_[e],trues[:1000]))
x2 = list(map(lambda e : l_[e],preds[:1000])) 
for a,b,c in zip(x1,x2,words[:1000]):
  print(f"word: {c} -- emotion: {a} -- predition: {b}")
# Out:
#               precision    recall  f1-score   support
#
#            1       0.24      0.94      0.38      3735
#            2       0.00      0.00      0.00      2403
#            3       0.92      0.01      0.01      3587
#            4       0.92      0.10      0.19      2003
#            5       0.00      0.00      0.00      2300
#            6       0.53      0.80      0.64      1273
#            7       0.00      0.00      0.00      2053
#            8       0.00      0.00      0.00      1245
#
#     accuracy                           0.26     18599
#    macro avg       0.33      0.23      0.15     18599
# weighted avg       0.36      0.26      0.14     18599
#
# [[3504    0    0    0    0  231    0    0]
#  [2281    0    0    0    0  122    0    0]
#  [3364    0   23    0    1  177   22    0]
#  [  65   46    0  208 1523  161    0    0]
#  [2232    0    0    0    0   68    0    0]
#  [ 250    0    0    0    0 1023    0    0]
#  [1955    0    0    0    1   97    0    0]
#  [1066    7    2   17   92   59    2    0]]
# word: I -- emotion: Joyful -- predition: Joyful
# word: guess -- emotion: Joyful -- predition: Joyful
# word: I -- emotion: Joyful -- predition: Joyful
# word: <unk> -- emotion: Joyful -- predition: Joyful
# word: thought -- emotion: Joyful -- predition: Joyful
# word: about -- emotion: Joyful -- predition: Joyful
# word: my -- emotion: Joyful -- predition: Joyful
# word: wife -- emotion: Joyful -- predition: Joyful
# word: and -- emotion: Joyful -- predition: Joyful
# word: kids -- emotion: Joyful -- predition: Joyful
# word: before -- emotion: Joyful -- predition: Joyful
# word: I -- emotion: Joyful -- predition: Joyful
# word: talked -- emotion: Joyful -- predition: Joyful
# word: back -- emotion: Joyful -- predition: Joyful
# word: to -- emotion: Joyful -- predition: Joyful
# word: chef -- emotion: Joyful -- predition: Joyful
# word: Geller -- emotion: Joyful -- predition: Joyful
# word: ! -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Thanks -- emotion: Joyful -- predition: Scared
# word: . -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Yep -- emotion: Powerful -- predition: Scared
# word: ! -- emotion: Powerful -- predition: Joyful
# word: Looks -- emotion: Powerful -- predition: Joyful
# word: like -- emotion: Powerful -- predition: Joyful
# word: <unk> -- emotion: Powerful -- predition: Joyful
# word: gonna -- emotion: Powerful -- predition: Joyful
# word: be -- emotion: Powerful -- predition: Joyful
# word: a -- emotion: Powerful -- predition: Joyful
# word: <unk> -- emotion: Powerful -- predition: Joyful
# word: Christmas -- emotion: Powerful -- predition: Joyful
# word: at -- emotion: Powerful -- predition: Joyful
# word: the -- emotion: Powerful -- predition: Joyful
# word: <unk> -- emotion: Powerful -- predition: Joyful
# word: house -- emotion: Powerful -- predition: Joyful
# word: this -- emotion: Powerful -- predition: Joyful
# word: year -- emotion: Powerful -- predition: Joyful
# word: . -- emotion: Powerful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Enough -- emotion: Sad -- predition: Scared
# word: ! -- emotion: Sad -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: <unk> -- emotion: Scared -- predition: Scared
# word: ! -- emotion: Scared -- predition: Scared
# word: could -- emotion: Neutral -- predition: Joyful
# word: you -- emotion: Neutral -- predition: Joyful
# word: have -- emotion: Neutral -- predition: Joyful
# word: told -- emotion: Neutral -- predition: Joyful
# word: her -- emotion: Neutral -- predition: Joyful
# word: ? -- emotion: Neutral -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Ross -- emotion: Sad -- predition: Scared
# word: , -- emotion: Sad -- predition: Joyful
# word: I -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: think -- emotion: Sad -- predition: Joyful
# word: it -- emotion: Sad -- predition: Joyful
# word: would -- emotion: Sad -- predition: Joyful
# word: that -- emotion: Sad -- predition: Joyful
# word: big -- emotion: Sad -- predition: Joyful
# word: of -- emotion: Sad -- predition: Joyful
# word: a -- emotion: Sad -- predition: Joyful
# word: deal -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Oh -- emotion: Sad -- predition: Scared
# word: , -- emotion: Sad -- predition: Joyful
# word: she -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: think -- emotion: Sad -- predition: Joyful
# word: it -- emotion: Sad -- predition: Joyful
# word: would -- emotion: Sad -- predition: Joyful
# word: be -- emotion: Sad -- predition: Joyful
# word: that -- emotion: Sad -- predition: Joyful
# word: big -- emotion: Sad -- predition: Joyful
# word: of -- emotion: Sad -- predition: Joyful
# word: deal -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Okay -- emotion: Neutral -- predition: Scared
# word: , -- emotion: Neutral -- predition: Joyful
# word: who -- emotion: Neutral -- predition: Joyful
# word: are -- emotion: Neutral -- predition: Joyful
# word: you -- emotion: Neutral -- predition: Joyful
# word: talking -- emotion: Neutral -- predition: Joyful
# word: to -- emotion: Neutral -- predition: Joyful
# word: when -- emotion: Neutral -- predition: Joyful
# word: you -- emotion: Neutral -- predition: Joyful
# word: do -- emotion: Neutral -- predition: Joyful
# word: that -- emotion: Neutral -- predition: Joyful
# word: ? -- emotion: Neutral -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Look -- emotion: Sad -- predition: Scared
# word: , -- emotion: Sad -- predition: Joyful
# word: that -- emotion: Sad -- predition: Joyful
# word: was -- emotion: Sad -- predition: Joyful
# word: supposed -- emotion: Sad -- predition: Joyful
# word: to -- emotion: Sad -- predition: Joyful
# word: be -- emotion: Sad -- predition: Joyful
# word: like -- emotion: Sad -- predition: Joyful
# word: a -- emotion: Sad -- predition: Joyful
# word: private -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: personal -- emotion: Sad -- predition: Joyful
# word: thing -- emotion: Sad -- predition: Joyful
# word: between -- emotion: Sad -- predition: Joyful
# word: us -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Okay -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: Ross -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: Phoebe -- emotion: Sad -- predition: Joyful
# word: is -- emotion: Sad -- predition: Joyful
# word: my -- emotion: Sad -- predition: Joyful
# word: girlfriend -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: okay -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: we -- emotion: Sad -- predition: Joyful
# word: tell -- emotion: Sad -- predition: Joyful
# word: each -- emotion: Sad -- predition: Joyful
# word: other -- emotion: Sad -- predition: Joyful
# word: everything -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: You -- emotion: Sad -- predition: Joyful
# word: know -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: I -- emotion: Sad -- predition: Joyful
# word: mean -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: come -- emotion: Sad -- predition: Joyful
# word: on -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: guys -- emotion: Sad -- predition: Joyful
# word: do -- emotion: Sad -- predition: Joyful
# word: the -- emotion: Sad -- predition: Joyful
# word: same -- emotion: Sad -- predition: Joyful
# word: thing -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: I -- emotion: Sad -- predition: Joyful
# word: mean -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: what -- emotion: Sad -- predition: Joyful
# word: about -- emotion: Sad -- predition: Joyful
# word: all -- emotion: Sad -- predition: Joyful
# word: that -- emotion: Sad -- predition: Joyful
# word: locker -- emotion: Sad -- predition: Joyful
# word: room -- emotion: Sad -- predition: Joyful
# word: stuff -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: different -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: okay -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: like -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: uh -- emotion: Sad -- predition: Joyful
# word: ' -- emotion: Sad -- predition: Joyful
# word: Who -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: a -- emotion: Sad -- predition: Joyful
# word: stripper -- emotion: Sad -- predition: Joyful
# word: ? -- emotion: Sad -- predition: Joyful
# word: ' -- emotion: Sad -- predition: Joyful
# word: or -- emotion: Sad -- predition: Joyful
# word: ' -- emotion: Sad -- predition: Joyful
# word: Who -- emotion: Sad -- predition: Joyful
# word: did -- emotion: Sad -- predition: Joyful
# word: it -- emotion: Sad -- predition: Joyful
# word: on -- emotion: Sad -- predition: Joyful
# word: the -- emotion: Sad -- predition: Joyful
# word: back -- emotion: Sad -- predition: Joyful
# word: of -- emotion: Sad -- predition: Joyful
# word: the -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: Island -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: ? -- emotion: Sad -- predition: Joyful
# word: ' -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Were -- emotion: Joyful -- predition: Joyful
# word: both -- emotion: Joyful -- predition: Joyful
# word: of -- emotion: Joyful -- predition: Joyful
# word: those -- emotion: Joyful -- predition: Joyful
# word: Joey -- emotion: Joyful -- predition: Joyful
# word: ? -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Yeah -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: Look -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: you -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: you -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: talk -- emotion: Sad -- predition: Joyful
# word: about -- emotion: Sad -- predition: Joyful
# word: like -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: you -- emotion: Sad -- predition: Joyful
# word: know -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: your -- emotion: Sad -- predition: Joyful
# word: girlfriend -- emotion: Sad -- predition: Joyful
# word: and -- emotion: Sad -- predition: Joyful
# word: the -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: stuff -- emotion: Sad -- predition: Joyful
# word: you -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: you -- emotion: Sad -- predition: Joyful
# word: do -- emotion: Sad -- predition: Joyful
# word: with -- emotion: Sad -- predition: Joyful
# word: her -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Not -- emotion: Joyful -- predition: Joyful
# word: even -- emotion: Joyful -- predition: Joyful
# word: with -- emotion: Joyful -- predition: Joyful
# word: your -- emotion: Joyful -- predition: Joyful
# word: best -- emotion: Joyful -- predition: Joyful
# word: friend -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Noo -- emotion: Sad -- predition: Joyful
# word: ! -- emotion: Sad -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: That -- emotion: Scared -- predition: Joyful
# word: is -- emotion: Scared -- predition: Joyful
# word: so -- emotion: Scared -- predition: Joyful
# word: sad -- emotion: Scared -- predition: Joyful
# word: . -- emotion: Scared -- predition: Joyful
# word: Your -- emotion: Scared -- predition: Joyful
# word: missing -- emotion: Scared -- predition: Joyful
# word: out -- emotion: Scared -- predition: Joyful
# word: on -- emotion: Scared -- predition: Joyful
# word: so -- emotion: Scared -- predition: Joyful
# word: much -- emotion: Scared -- predition: Joyful
# word: , -- emotion: Scared -- predition: Joyful
# word: Ross -- emotion: Scared -- predition: Joyful
# word: . -- emotion: Scared -- predition: Joyful
# word: I -- emotion: Scared -- predition: Joyful
# word: mean -- emotion: Scared -- predition: Joyful
# word: , -- emotion: Scared -- predition: Joyful
# word: the -- emotion: Scared -- predition: Joyful
# word: bonding -- emotion: Scared -- predition: Joyful
# word: and -- emotion: Scared -- predition: Joyful
# word: the -- emotion: Scared -- predition: Joyful
# word: sharing -- emotion: Scared -- predition: Joyful
# word: , -- emotion: Scared -- predition: Joyful
# word: you -- emotion: Scared -- predition: Joyful
# word: know -- emotion: Scared -- predition: Joyful
# word: . -- emotion: Scared -- predition: Joyful
# word: <unk> -- emotion: Scared -- predition: Joyful
# word: knowing -- emotion: Scared -- predition: Joyful
# word: that -- emotion: Scared -- predition: Joyful
# word: someone -- emotion: Scared -- predition: Joyful
# word: else -- emotion: Scared -- predition: Joyful
# word: is -- emotion: Scared -- predition: Joyful
# word: going -- emotion: Scared -- predition: Joyful
# word: through -- emotion: Scared -- predition: Joyful
# word: the -- emotion: Scared -- predition: Joyful
# word: same -- emotion: Scared -- predition: Joyful
# word: thing -- emotion: Scared -- predition: Joyful
# word: you -- emotion: Scared -- predition: Joyful
# word: are -- emotion: Scared -- predition: Joyful
# word: . -- emotion: Scared -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: <unk> -- emotion: Neutral -- predition: Joyful
# word: . -- emotion: Neutral -- predition: Joyful
# word: So -- emotion: Neutral -- predition: Joyful
# word: what -- emotion: Neutral -- predition: Joyful
# word: you -- emotion: Neutral -- predition: Joyful
# word: , -- emotion: Neutral -- predition: Joyful
# word: you -- emotion: Neutral -- predition: Joyful
# word: tell -- emotion: Neutral -- predition: Joyful
# word: each -- emotion: Neutral -- predition: Joyful
# word: other -- emotion: Neutral -- predition: Joyful
# word: everything -- emotion: Neutral -- predition: Joyful
# word: ? -- emotion: Neutral -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Pretty -- emotion: Powerful -- predition: Joyful
# word: much -- emotion: Powerful -- predition: Joyful
# word: . -- emotion: Powerful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Did -- emotion: Joyful -- predition: Joyful
# word: you -- emotion: Joyful -- predition: Joyful
# word: talk -- emotion: Joyful -- predition: Joyful
# word: about -- emotion: Joyful -- predition: Joyful
# word: the -- emotion: Joyful -- predition: Joyful
# word: night -- emotion: Joyful -- predition: Joyful
# word: of -- emotion: Joyful -- predition: Joyful
# word: five -- emotion: Joyful -- predition: Joyful
# word: times -- emotion: Joyful -- predition: Joyful
# word: ? -- emotion: Joyful -- predition: Joyful
# word: Do -- emotion: Joyful -- predition: Joyful
# word: you -- emotion: Joyful -- predition: Joyful
# word: tell -- emotion: Joyful -- predition: Joyful
# word: people -- emotion: Joyful -- predition: Joyful
# word: about -- emotion: Joyful -- predition: Joyful
# word: the -- emotion: Joyful -- predition: Joyful
# word: night -- emotion: Joyful -- predition: Joyful
# word: of -- emotion: Joyful -- predition: Joyful
# word: five -- emotion: Joyful -- predition: Joyful
# word: times -- emotion: Joyful -- predition: Joyful
# word: ? -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Uh -- emotion: Powerful -- predition: Joyful
# word: , -- emotion: Powerful -- predition: Joyful
# word: honey -- emotion: Powerful -- predition: Joyful
# word: , -- emotion: Powerful -- predition: Joyful
# word: yeah -- emotion: Powerful -- predition: Joyful
# word: that -- emotion: Powerful -- predition: Joyful
# word: was -- emotion: Powerful -- predition: Joyful
# word: with -- emotion: Powerful -- predition: Joyful
# word: Carol -- emotion: Powerful -- predition: Joyful
# word: . -- emotion: Powerful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: I -- emotion: Neutral -- predition: Joyful
# word: know -- emotion: Neutral -- predition: Joyful
# word: , -- emotion: Neutral -- predition: Joyful
# word: but -- emotion: Neutral -- predition: Joyful
# word: <unk> -- emotion: Neutral -- predition: Joyful
# word: still -- emotion: Neutral -- predition: Joyful
# word: worth -- emotion: Neutral -- predition: Joyful
# word: <unk> -- emotion: Neutral -- predition: Joyful
# word: , -- emotion: Neutral -- predition: Joyful
# word: I -- emotion: Neutral -- predition: Joyful
# word: think -- emotion: Neutral -- predition: Joyful
# word: . -- emotion: Neutral -- predition: Joyful
# word: , -- emotion: Neutral -- predition: Joyful
# word: look -- emotion: Neutral -- predition: Joyful
# word: what -- emotion: Neutral -- predition: Joyful
# word: I -- emotion: Neutral -- predition: Joyful
# word: found -- emotion: Neutral -- predition: Joyful
# word: in -- emotion: Neutral -- predition: Joyful
# word: the -- emotion: Neutral -- predition: Joyful
# word: drain -- emotion: Neutral -- predition: Joyful
# word: . -- emotion: Neutral -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: What -- emotion: Neutral -- predition: Scared
# word: ? -- emotion: Neutral -- predition: Joyful
# word: ! -- emotion: Neutral -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: <unk> -- emotion: Neutral -- predition: Scared
# word: some -- emotion: Neutral -- predition: Joyful
# word: of -- emotion: Neutral -- predition: Joyful
# word: <unk> -- emotion: Neutral -- predition: Joyful
# word: hair -- emotion: Neutral -- predition: Joyful
# word: ! -- emotion: Neutral -- predition: Joyful
# word: What -- emotion: Neutral -- predition: Joyful
# word: do -- emotion: Neutral -- predition: Joyful
# word: I -- emotion: Neutral -- predition: Joyful
# word: do -- emotion: Neutral -- predition: Joyful
# word: with -- emotion: Neutral -- predition: Joyful
# word: this -- emotion: Neutral -- predition: Joyful
# word: ? -- emotion: Neutral -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: <unk> -- emotion: Joyful -- predition: Scared
# word: it -- emotion: Joyful -- predition: Joyful
# word: away -- emotion: Joyful -- predition: Joyful
# word: from -- emotion: Joyful -- predition: Joyful
# word: me -- emotion: Joyful -- predition: Joyful
# word: would -- emotion: Joyful -- predition: Joyful
# word: be -- emotion: Joyful -- predition: Joyful
# word: job -- emotion: Joyful -- predition: Joyful
# word: one -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: <unk> -- emotion: Neutral -- predition: Scared
# word: weird -- emotion: Neutral -- predition: Joyful
# word: , -- emotion: Neutral -- predition: Joyful
# word: but -- emotion: Neutral -- predition: Joyful
# word: you -- emotion: Neutral -- predition: Joyful
# word: know -- emotion: Neutral -- predition: Joyful
# word: what -- emotion: Neutral -- predition: Joyful
# word: I -- emotion: Neutral -- predition: Joyful
# word: <unk> -- emotion: Neutral -- predition: Joyful
# word: wanna -- emotion: Neutral -- predition: Joyful
# word: throw -- emotion: Neutral -- predition: Joyful
# word: this -- emotion: Neutral -- predition: Joyful
# word: away -- emotion: Neutral -- predition: Joyful
# word: . -- emotion: Neutral -- predition: Joyful
# word: I -- emotion: Neutral -- predition: Joyful
# word: mean -- emotion: Neutral -- predition: Joyful
# word: this -- emotion: Neutral -- predition: Joyful
# word: is -- emotion: Neutral -- predition: Joyful
# word: like -- emotion: Neutral -- predition: Joyful
# word: all -- emotion: Neutral -- predition: Joyful
# word: I -- emotion: Neutral -- predition: Joyful
# word: have -- emotion: Neutral -- predition: Joyful
# word: left -- emotion: Neutral -- predition: Joyful
# word: of -- emotion: Neutral -- predition: Joyful
# word: him -- emotion: Neutral -- predition: Joyful
# word: , -- emotion: Neutral -- predition: Joyful
# word: gross -- emotion: Neutral -- predition: Joyful
# word: , -- emotion: Neutral -- predition: Joyful
# word: drain -- emotion: Neutral -- predition: Joyful
# word: hair -- emotion: Neutral -- predition: Joyful
# word: . -- emotion: Neutral -- predition: Joyful
# word: Ooh -- emotion: Neutral -- predition: Joyful
# word: ! -- emotion: Neutral -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Ooh -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: Oh -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: It -- emotion: Joyful -- predition: Joyful
# word: looks -- emotion: Joyful -- predition: Joyful
# word: like -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: like -- emotion: Joyful -- predition: Joyful
# word: a -- emotion: Joyful -- predition: Joyful
# word: tiny -- emotion: Joyful -- predition: Joyful
# word: little -- emotion: Joyful -- predition: Joyful
# word: person -- emotion: Joyful -- predition: Joyful
# word: <unk> -- emotion: Joyful -- predition: Joyful
# word: in -- emotion: Joyful -- predition: Joyful
# word: your -- emotion: Joyful -- predition: Joyful
# word: cereal -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: God -- emotion: Scared -- predition: Joyful
# word: , -- emotion: Scared -- predition: Joyful
# word: what -- emotion: Scared -- predition: Joyful
# word: is -- emotion: Scared -- predition: Joyful
# word: wrong -- emotion: Scared -- predition: Joyful
# word: with -- emotion: Scared -- predition: Joyful
# word: me -- emotion: Scared -- predition: Joyful
# word: . -- emotion: Scared -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: You -- emotion: Joyful -- predition: Joyful
# word: need -- emotion: Joyful -- predition: Joyful
# word: to -- emotion: Joyful -- predition: Joyful
# word: get -- emotion: Joyful -- predition: Joyful
# word: some -- emotion: Joyful -- predition: Joyful
# word: sleep -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: I -- emotion: Scared -- predition: Joyful
# word: need -- emotion: Scared -- predition: Joyful
# word: to -- emotion: Scared -- predition: Joyful
# word: get -- emotion: Scared -- predition: Joyful
# word: some -- emotion: Scared -- predition: Joyful
# word: Richard -- emotion: Scared -- predition: Joyful
# word: . -- emotion: Scared -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Monica -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: you -- emotion: Joyful -- predition: Joyful
# word: broke -- emotion: Joyful -- predition: Joyful
# word: up -- emotion: Joyful -- predition: Joyful
# word: with -- emotion: Joyful -- predition: Joyful
# word: him -- emotion: Joyful -- predition: Joyful
# word: for -- emotion: Joyful -- predition: Joyful
# word: a -- emotion: Joyful -- predition: Joyful
# word: reason -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: I -- emotion: Scared -- predition: Joyful
# word: know -- emotion: Scared -- predition: Joyful
# word: , -- emotion: Scared -- predition: Joyful
# word: I -- emotion: Scared -- predition: Joyful
# word: know -- emotion: Scared -- predition: Joyful
# word: . -- emotion: Scared -- predition: Joyful
# word: <unk> -- emotion: Scared -- predition: Joyful
# word: just -- emotion: Scared -- predition: Joyful
# word: so -- emotion: Scared -- predition: Joyful
# word: tired -- emotion: Scared -- predition: Joyful
# word: <unk> -- emotion: Scared -- predition: Joyful
# word: missing -- emotion: Scared -- predition: Joyful
# word: him -- emotion: Scared -- predition: Joyful
# word: . -- emotion: Scared -- predition: Joyful
# word: <unk> -- emotion: Scared -- predition: Joyful
# word: tired -- emotion: Scared -- predition: Joyful
# word: of -- emotion: Scared -- predition: Joyful
# word: wondering -- emotion: Scared -- predition: Joyful
# word: why -- emotion: Scared -- predition: Joyful
# word: <unk> -- emotion: Scared -- predition: Joyful
# word: he -- emotion: Scared -- predition: Joyful
# word: called -- emotion: Scared -- predition: Joyful
# word: . -- emotion: Scared -- predition: Joyful
# word: Why -- emotion: Scared -- predition: Joyful
# word: <unk> -- emotion: Scared -- predition: Joyful
# word: he -- emotion: Scared -- predition: Joyful
# word: called -- emotion: Scared -- predition: Joyful
# word: ! -- emotion: Scared -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Maybe -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: because -- emotion: Joyful -- predition: Joyful
# word: you -- emotion: Joyful -- predition: Joyful
# word: told -- emotion: Joyful -- predition: Joyful
# word: him -- emotion: Joyful -- predition: Joyful
# word: not -- emotion: Joyful -- predition: Joyful
# word: to -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: What -- emotion: Sad -- predition: Joyful
# word: are -- emotion: Sad -- predition: Joyful
# word: you -- emotion: Sad -- predition: Joyful
# word: the -- emotion: Sad -- predition: Joyful
# word: memory -- emotion: Sad -- predition: Joyful
# word: woman -- emotion: Sad -- predition: Joyful
# word: ? -- emotion: Sad -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: <unk> -- emotion: Joyful -- predition: Joyful
# word: not -- emotion: Joyful -- predition: Joyful
# word: breaking -- emotion: Joyful -- predition: Joyful
# word: up -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: Chandler -- emotion: Joyful -- predition: Joyful
# word: and -- emotion: Joyful -- predition: Joyful
# word: Janice -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: <unk> -- emotion: Joyful -- predition: Joyful
# word: not -- emotion: Joyful -- predition: Joyful
# word: breaking -- emotion: Joyful -- predition: Joyful
# word: up -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: He -- emotion: Joyful -- predition: Joyful
# word: <unk> -- emotion: Joyful -- predition: Joyful
# word: <unk> -- emotion: Joyful -- predition: Joyful
# word: or -- emotion: Joyful -- predition: Joyful
# word: anything -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Well -- emotion: Powerful -- predition: Joyful
# word: , -- emotion: Powerful -- predition: Joyful
# word: you -- emotion: Powerful -- predition: Joyful
# word: know -- emotion: Powerful -- predition: Joyful
# word: <unk> -- emotion: Powerful -- predition: Joyful
# word: not -- emotion: Powerful -- predition: Joyful
# word: surprised -- emotion: Powerful -- predition: Joyful
# word: . -- emotion: Powerful -- predition: Joyful
# word: I -- emotion: Powerful -- predition: Joyful
# word: mean -- emotion: Powerful -- predition: Joyful
# word: have -- emotion: Powerful -- predition: Joyful
# word: you -- emotion: Powerful -- predition: Joyful
# word: seen -- emotion: Powerful -- predition: Joyful
# word: them -- emotion: Powerful -- predition: Joyful
# word: together -- emotion: Powerful -- predition: Joyful
# word: , -- emotion: Powerful -- predition: Joyful
# word: <unk> -- emotion: Powerful -- predition: Joyful
# word: really -- emotion: Powerful -- predition: Joyful
# word: cute -- emotion: Powerful -- predition: Joyful
# word: . -- emotion: Powerful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: ! -- emotion: Sad -- predition: Joyful
# word: This -- emotion: Sad -- predition: Joyful
# word: is -- emotion: Sad -- predition: Joyful
# word: Janice -- emotion: Sad -- predition: Joyful
# word: ! -- emotion: Sad -- predition: Joyful
# word: You -- emotion: Sad -- predition: Joyful
# word: remember -- emotion: Sad -- predition: Joyful
# word: Janice -- emotion: Sad -- predition: Joyful
# word: ? -- emotion: Sad -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Yes -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: Joey -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: I -- emotion: Joyful -- predition: Joyful
# word: remember -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: <unk> -- emotion: Joyful -- predition: Joyful
# word: annoying -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: but -- emotion: Joyful -- predition: Joyful
# word: you -- emotion: Joyful -- predition: Joyful
# word: know -- emotion: Joyful -- predition: Joyful
# word: what -- emotion: Joyful -- predition: Joyful
# word: <unk> -- emotion: Joyful -- predition: Joyful
# word: his -- emotion: Joyful -- predition: Joyful
# word: girlfriend -- emotion: Joyful -- predition: Joyful
# word: now -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: I -- emotion: Joyful -- predition: Joyful
# word: mean -- emotion: Joyful -- predition: Joyful
# word: what -- emotion: Joyful -- predition: Joyful
# word: can -- emotion: Joyful -- predition: Joyful
# word: we -- emotion: Joyful -- predition: Joyful
# word: do -- emotion: Joyful -- predition: Joyful
# word: ? -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: There -- emotion: Powerful -- predition: Joyful
# word: you -- emotion: Powerful -- predition: Joyful
# word: go -- emotion: Powerful -- predition: Joyful
# word: ! -- emotion: Powerful -- predition: Joyful
# word: <unk> -- emotion: Powerful -- predition: Joyful
# word: the -- emotion: Powerful -- predition: Joyful
# word: spirit -- emotion: Powerful -- predition: Joyful
# word: <unk> -- emotion: Powerful -- predition: Joyful
# word: looking -- emotion: Powerful -- predition: Joyful
# word: for -- emotion: Powerful -- predition: Joyful
# word: ! -- emotion: Powerful -- predition: Joyful
# word: What -- emotion: Powerful -- predition: Joyful
# word: can -- emotion: Powerful -- predition: Joyful
# word: we -- emotion: Powerful -- predition: Joyful
# word: do -- emotion: Powerful -- predition: Joyful
# word: ? -- emotion: Powerful -- predition: Joyful
# word: Huh -- emotion: Powerful -- predition: Joyful
# word: ? -- emotion: Powerful -- predition: Joyful
# word: All -- emotion: Powerful -- predition: Joyful
# word: right -- emotion: Powerful -- predition: Joyful
# word: <unk> -- emotion: Powerful -- predition: Joyful
# word: first -- emotion: Powerful -- predition: Joyful
# word: ? -- emotion: Powerful -- predition: Joyful
# word: Huh -- emotion: Powerful -- predition: Joyful
# word: ? -- emotion: Powerful -- predition: Joyful
# word: Ross -- emotion: Powerful -- predition: Joyful
# word: ? -- emotion: Powerful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Well -- emotion: Joyful -- predition: Joyful
# word: <unk> -- emotion: Joyful -- predition: Joyful
# word: thinking -- emotion: Joyful -- predition: Joyful
# word: that -- emotion: Joyful -- predition: Joyful
# word: <unk> -- emotion: Joyful -- predition: Joyful
# word: our -- emotion: Joyful -- predition: Joyful
# word: friend -- emotion: Joyful -- predition: Joyful
# word: and -- emotion: Joyful -- predition: Joyful
# word: Janice -- emotion: Joyful -- predition: Joyful
# word: makes -- emotion: Joyful -- predition: Joyful
# word: him -- emotion: Joyful -- predition: Joyful
# word: happy -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: so -- emotion: Joyful -- predition: Joyful
# word: I -- emotion: Joyful -- predition: Joyful
# word: say -- emotion: Joyful -- predition: Joyful
# word: we -- emotion: Joyful -- predition: Joyful
# word: just -- emotion: Joyful -- predition: Joyful
# word: all -- emotion: Joyful -- predition: Joyful
# word: be -- emotion: Joyful -- predition: Joyful
# word: adult -- emotion: Joyful -- predition: Joyful
# word: about -- emotion: Joyful -- predition: Joyful
# word: it -- emotion: Joyful -- predition: Joyful
# word: and -- emotion: Joyful -- predition: Joyful
# word: accept -- emotion: Joyful -- predition: Joyful
# word: her -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Yeah -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: <unk> -- emotion: Joyful -- predition: Joyful
# word: call -- emotion: Joyful -- predition: Joyful
# word: that -- emotion: Joyful -- predition: Joyful
# word: <unk> -- emotion: Joyful -- predition: Joyful
# word: B -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: All -- emotion: Joyful -- predition: Joyful
# word: right -- emotion: Joyful -- predition: Joyful
# word: ? -- emotion: Joyful -- predition: Joyful
# word: ! -- emotion: Powerful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: <unk> -- emotion: Powerful -- predition: Scared
# word: ! -- emotion: Powerful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Of -- emotion: Powerful -- predition: Scared
# word: ! -- emotion: Powerful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Scared
# word: ! -- emotion: Sad -- predition: Joyful
# word: This -- emotion: Sad -- predition: Joyful
# word: guy -- emotion: Sad -- predition: Joyful
# word: is -- emotion: Sad -- predition: Joyful
# word: so -- emotion: Sad -- predition: Joyful
# word: stupid -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: Count -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: ! -- emotion: Sad -- predition: Joyful
# word: ! -- emotion: Sad -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: You -- emotion: Powerful -- predition: Scared
# word: know -- emotion: Powerful -- predition: Joyful
# word: , -- emotion: Powerful -- predition: Joyful
# word: you -- emotion: Powerful -- predition: Joyful
# word: should -- emotion: Powerful -- predition: Joyful
# word: really -- emotion: Powerful -- predition: Joyful
# word: go -- emotion: Powerful -- predition: Joyful
# word: on -- emotion: Powerful -- predition: Joyful
# word: this -- emotion: Powerful -- predition: Joyful
# word: show -- emotion: Powerful -- predition: Joyful
# word: . -- emotion: Powerful -- predition: Joyful
# word: All -- emotion: Powerful -- predition: Joyful
# word: right -- emotion: Powerful -- predition: Joyful
# word: , -- emotion: Powerful -- predition: Joyful
# word: listen -- emotion: Powerful -- predition: Joyful
# word: , -- emotion: Powerful -- predition: Joyful
# word: I -- emotion: Powerful -- predition: Joyful
# word: got -- emotion: Powerful -- predition: Joyful
# word: three -- emotion: Powerful -- predition: Joyful
# word: tickets -- emotion: Powerful -- predition: Joyful
# word: to -- emotion: Powerful -- predition: Joyful
# word: the -- emotion: Powerful -- predition: Joyful
# word: <unk> -- emotion: Powerful -- predition: Joyful
# word: tonight -- emotion: Powerful -- predition: Joyful
# word: . -- emotion: Powerful -- predition: Joyful
# word: <unk> -- emotion: Powerful -- predition: Joyful
# word: ya -- emotion: Powerful -- predition: Joyful
# word: ' -- emotion: Powerful -- predition: Joyful
# word: say -- emotion: Powerful -- predition: Joyful
# word: ? -- emotion: Powerful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: I -- emotion: Joyful -- predition: Scared
# word: say -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: ' -- emotion: Joyful -- predition: Joyful
# word: I -- emotion: Joyful -- predition: Joyful
# word: am -- emotion: Joyful -- predition: Joyful
# word: there -- emotion: Joyful -- predition: Joyful
# word: ! -- emotion: Joyful -- predition: Joyful
# word: ' -- emotion: Joyful -- predition: Joyful
# word: Cool -- emotion: Joyful -- predition: Joyful
# word: ! -- emotion: Joyful -- predition: Joyful
# word: Aw -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: is -- emotion: Joyful -- predition: Joyful
# word: Ross -- emotion: Joyful -- predition: Joyful
# word: going -- emotion: Joyful -- predition: Joyful
# word: to -- emotion: Joyful -- predition: Joyful
# word: ? -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: No -- emotion: Joyful -- predition: Scared
# word: , -- emotion: Joyful -- predition: Joyful
# word: Janice -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: <unk> -- emotion: Scared -- predition: Scared
# word: . -- emotion: Scared -- predition: Scared
# word: ' -- emotion: Scared -- predition: Scared
# word: Cause -- emotion: Scared -- predition: Scared
# word: I -- emotion: Scared -- predition: Scared
# word: , -- emotion: Scared -- predition: Scared
# word: just -- emotion: Scared -- predition: Scared
# word: , -- emotion: Scared -- predition: Scared
# word: I -- emotion: Scared -- predition: Scared
# word: feel -- emotion: Scared -- predition: Scared
# word: bad -- emotion: Scared -- predition: Scared
# word: for -- emotion: Scared -- predition: Scared
# word: Ross -- emotion: Scared -- predition: Scared
# word: , -- emotion: Scared -- predition: Scared
# word: you -- emotion: Scared -- predition: Scared
# word: know -- emotion: Scared -- predition: Scared
# word: , -- emotion: Scared -- predition: Scared
# word: <unk> -- emotion: Scared -- predition: Scared
# word: always -- emotion: Scared -- predition: Scared
# word: go -- emotion: Scared -- predition: Scared
# word: together -- emotion: Scared -- predition: Scared
# word: , -- emotion: Scared -- predition: Scared
# word: <unk> -- emotion: Scared -- predition: Scared
# word: like -- emotion: Scared -- predition: Scared
# word: the -- emotion: Scared -- predition: Scared
# word: three -- emotion: Scared -- predition: Scared
# word: <unk> -- emotion: Scared -- predition: Scared
# word: . -- emotion: Scared -- predition: Scared
# word: <sep> -- emotion: NE -- predition: Scared
# word: You -- emotion: Joyful -- predition: Scared
# word: know -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: I -- emotion: Joyful -- predition: Joyful
# word: may -- emotion: Joyful -- predition: Joyful
# word: be -- emotion: Joyful -- predition: Joyful
# word: way -- emotion: Joyful -- predition: Joyful
# word: out -- emotion: Joyful -- predition: Joyful
# word: on -- emotion: Joyful -- predition: Joyful
# word: a -- emotion: Joyful -- predition: Joyful
# word: <unk> -- emotion: Joyful -- predition: Joyful
# word: here -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: but -- emotion: Joyful -- predition: Joyful
# word: do -- emotion: Joyful -- predition: Joyful
# word: you -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: do -- emotion: Joyful -- predition: Joyful
# word: you -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: have -- emotion: Joyful -- predition: Joyful
# word: a -- emotion: Joyful -- predition: Joyful
# word: problem -- emotion: Joyful -- predition: Joyful
# word: with -- emotion: Joyful -- predition: Joyful
# word: Janice -- emotion: Joyful -- predition: Joyful
# word: ? -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: No -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: God -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: how -- emotion: Sad -- predition: Joyful
# word: do -- emotion: Sad -- predition: Joyful
# word: I -- emotion: Sad -- predition: Joyful
# word: say -- emotion: Sad -- predition: Joyful
# word: this -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: Oh -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: hi -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: you -- emotion: Sad -- predition: Joyful
# word: know -- emotion: Sad -- predition: Joyful
# word: that -- emotion: Sad -- predition: Joyful
# word: girl -- emotion: Sad -- predition: Joyful
# word: from -- emotion: Sad -- predition: Joyful
# word: the -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: restaurant -- emotion: Sad -- predition: Joyful
# word: with -- emotion: Sad -- predition: Joyful
# word: the -- emotion: Sad -- predition: Joyful
# word: hair -- emotion: Sad -- predition: Joyful
# word: ? -- emotion: Sad -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Ooh -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: that -- emotion: Sad -- predition: Joyful
# word: girl -- emotion: Sad -- predition: Joyful
# word: that -- emotion: Sad -- predition: Joyful
# word: I -- emotion: Sad -- predition: Joyful
# word: hate -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: eww -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: drives -- emotion: Sad -- predition: Joyful
# word: me -- emotion: Sad -- predition: Joyful
# word: crazy -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: eww -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: eww -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: oh -- emotion: Sad -- predition: Joyful
# word: ! -- emotion: Sad -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Look -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: I -- emotion: Joyful -- predition: Joyful
# word: <unk> -- emotion: Joyful -- predition: Joyful
# word: hate -- emotion: Joyful -- predition: Joyful
# word: Janice -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: <unk> -- emotion: Joyful -- predition: Joyful
# word: just -- emotion: Joyful -- predition: Joyful
# word: a -- emotion: Joyful -- predition: Joyful
# word: lot -- emotion: Joyful -- predition: Joyful
# word: to -- emotion: Joyful -- predition: Joyful
# word: take -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: you -- emotion: Joyful -- predition: Joyful
# word: know -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Well -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: there -- emotion: Joyful -- predition: Joyful
# word: you -- emotion: Joyful -- predition: Joyful
# word: go -- emotion: Joyful -- predition: Joyful
# word: . -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Oh -- emotion: Mad -- predition: Joyful
# word: , -- emotion: Mad -- predition: Joyful
# word: hey -- emotion: Mad -- predition: Joyful
# word: . -- emotion: Mad -- predition: Joyful
# word: Come -- emotion: Mad -- predition: Joyful
# word: on -- emotion: Mad -- predition: Joyful
# word: man -- emotion: Mad -- predition: Joyful
# word: , -- emotion: Mad -- predition: Joyful
# word: <unk> -- emotion: Mad -- predition: Joyful
# word: look -- emotion: Mad -- predition: Joyful
# word: at -- emotion: Mad -- predition: Joyful
# word: me -- emotion: Mad -- predition: Joyful
# word: like -- emotion: Mad -- predition: Joyful
# word: that -- emotion: Mad -- predition: Scared
# word: , -- emotion: Mad -- predition: Scared
# word: she -- emotion: Mad -- predition: Scared
# word: used -- emotion: Mad -- predition: Scared
# word: to -- emotion: Mad -- predition: Scared
# word: drive -- emotion: Mad -- predition: Scared
# word: you -- emotion: Mad -- predition: Scared
# word: nuts -- emotion: Mad -- predition: Scared
# word: before -- emotion: Mad -- predition: Scared
# word: too -- emotion: Mad -- predition: Scared
# word: , -- emotion: Mad -- predition: Scared
# word: remember -- emotion: Mad -- predition: Scared
# word: ? -- emotion: Mad -- predition: Scared
# word: <sep> -- emotion: NE -- predition: Scared
# word: Well -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: crazy -- emotion: Sad -- predition: Joyful
# word: about -- emotion: Sad -- predition: Joyful
# word: her -- emotion: Sad -- predition: Joyful
# word: now -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: I -- emotion: Sad -- predition: Joyful
# word: think -- emotion: Sad -- predition: Joyful
# word: this -- emotion: Sad -- predition: Joyful
# word: could -- emotion: Sad -- predition: Joyful
# word: be -- emotion: Sad -- predition: Joyful
# word: the -- emotion: Sad -- predition: Joyful
# word: real -- emotion: Sad -- predition: Joyful
# word: thing -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: ' -- emotion: Sad -- predition: Joyful
# word: R -- emotion: Sad -- predition: Joyful
# word: ' -- emotion: Sad -- predition: Joyful
# word: ! -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: ' -- emotion: Sad -- predition: Joyful
# word: T -- emotion: Sad -- predition: Joyful
# word: ' -- emotion: Sad -- predition: Joyful
# word: ! -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: worry -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: those -- emotion: Sad -- predition: Joyful
# word: are -- emotion: Sad -- predition: Joyful
# word: the -- emotion: Sad -- predition: Joyful
# word: right -- emotion: Sad -- predition: Joyful
# word: letters -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Look -- emotion: Joyful -- predition: Joyful
# word: , -- emotion: Joyful -- predition: Joyful
# word: what -- emotion: Joyful -- predition: Joyful
# word: do -- emotion: Joyful -- predition: Joyful
# word: you -- emotion: Joyful -- predition: Joyful
# word: want -- emotion: Joyful -- predition: Joyful
# word: me -- emotion: Joyful -- predition: Joyful
# word: to -- emotion: Joyful -- predition: Joyful
# word: say -- emotion: Joyful -- predition: Joyful
# word: ? -- emotion: Joyful -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: I -- emotion: Sad -- predition: Joyful
# word: want -- emotion: Sad -- predition: Joyful
# word: you -- emotion: Sad -- predition: Joyful
# word: to -- emotion: Sad -- predition: Joyful
# word: say -- emotion: Sad -- predition: Joyful
# word: that -- emotion: Sad -- predition: Joyful
# word: you -- emotion: Sad -- predition: Joyful
# word: like -- emotion: Sad -- predition: Joyful
# word: her -- emotion: Sad -- predition: Joyful
# word: ! -- emotion: Sad -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: I -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: like -- emotion: Sad -- predition: Joyful
# word: this -- emotion: Sad -- predition: Joyful
# word: <unk> -- emotion: Sad -- predition: Joyful
# word: thing -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: you -- emotion: Sad -- predition: Joyful
# word: know -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: Every -- emotion: Sad -- predition: Joyful
# word: time -- emotion: Sad -- predition: Joyful
# word: she -- emotion: Sad -- predition: Joyful
# word: starts -- emotion: Sad -- predition: Joyful
# word: laughing -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: I -- emotion: Sad -- predition: Joyful
# word: just -- emotion: Sad -- predition: Joyful
# word: wanna -- emotion: Sad -- predition: Joyful
# word: pull -- emotion: Sad -- predition: Joyful
# word: my -- emotion: Sad -- predition: Joyful
# word: arm -- emotion: Sad -- predition: Joyful
# word: off -- emotion: Sad -- predition: Joyful
# word: just -- emotion: Sad -- predition: Joyful
# word: so -- emotion: Sad -- predition: Joyful
# word: that -- emotion: Sad -- predition: Joyful
# word: I -- emotion: Sad -- predition: Joyful
# word: can -- emotion: Sad -- predition: Joyful
# word: have -- emotion: Sad -- predition: Joyful
# word: something -- emotion: Sad -- predition: Joyful
# word: to -- emotion: Sad -- predition: Joyful
# word: throw -- emotion: Sad -- predition: Joyful
# word: at -- emotion: Sad -- predition: Joyful
# word: her -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: <sep> -- emotion: NE -- predition: Joyful
# word: Thanks -- emotion: Sad -- predition: Joyful
# word: for -- emotion: Sad -- predition: Joyful
# word: trying -- emotion: Sad -- predition: Joyful
# word: . -- emotion: Sad -- predition: Joyful
# word: Oh -- emotion: Sad -- predition: Joyful
# word: , -- emotion: Sad -- predition: Joyful
# word: and -- emotion: Sad -- predition: Joyful
# /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/Anaconda3-2023.07-1/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
## finish later:

def eval_sentence(model, sentence, encoded_sentence, emotions, device):
  model.eval()
  for i in range(len(sentence) - 1):
    pe, _ = model.forward(encoded_sentence[i].to(device),emotions[i].to(device))
    t = torch.max(pe,1)
    print(f"word:{sentence[i+1]}; predicted_emotion: {t} ; target_emotion: {emotions[i+1]}")

# eval_sentence(model,sentence,encod,emot,device)
